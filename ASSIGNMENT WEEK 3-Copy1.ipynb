# %% [markdown]
# # Assignment Week3

# %%
data=pd.read_excel(r"C:\Users\pspra\Documents\Data Science and Analytics\Assignment_1\iris.xls.xls")

# %%
data.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# # Displaying columns in the dataset

# %%
data.head()
for columns in data.columns:
    print(columns)
# Out:
# SL
# SW
# PL
# PW
# Classification

# %% [markdown]
# # checking null values

# %%
data.head()
haveNull=data.isnull().values.any()
if(haveNull):
    print("There are null values")
else:
    print("There are no null values")
# Out:
# There are no null values

# %% [markdown]
# # Three Visualizations.

# %%
import matplotlib.pyplot as plt

# %%
data.head()
plt.scatter(data['Classification'],data['SW'])
plt.title("Sepal Width Vs classification",fontsize=20,pad=20)
plt.xlabel("Classification",frontsize=15,labelpad=10)
plt.ylabel("Sepal Width",fontsize=15,labelpad=10)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-e1298ce0d374> in <module>
#       2 plt.scatter(data['Classification'],data['SW'])
#       3 plt.title("Sepal Width Vs classification",fontsize=20,pad=20)
# ----> 4 plt.xlabel("Classification",frontsize=15,labelpad=10)
#       5 plt.ylabel("Sepal Width",fontsize=15,labelpad=10)
#       6 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    3113 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    3114 def xlabel(xlabel, fontdict=None, labelpad=None, *, loc=None, **kwargs):
# -> 3115     return gca().set_xlabel(
#    3116         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc,
#    3117         **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#     245         elif loc == 'right':
#     246             kwargs.update(x=1, horizontalalignment='right')
# --> 247         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     248
#     249     def get_ylabel(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1564         if fontdict is not None:
#    1565             self.label.update(fontdict)
# -> 1566         self.label.update(kwargs)
#    1567         self.stale = True
#    1568         return self.label
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     177         # Update bbox last, as it depends on font properties.
#     178         bbox = kwargs.pop("bbox", sentinel)
# --> 179         super().update(kwargs)
#     180         if bbox is not sentinel:
#     181             self.set_bbox(bbox)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'Text' object has no property 'frontsize'

# %%
import seaborn as sns
data.head()
p=sns.jointplot(x=data.PW,y=data.PL,hue=data['Classification']).set_axis_labels('Petal length')
p.fig.suptitle("Petal length and width distribution of each species",y=1.02,fontsize=16)
# Out:
# Text(0.5, 1.02, 'Petal length and width distribution of each species')

# %% [markdown]
# # Mean of each column

# %%
data.head()
data.mean(axis=0,skipna= True)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64
